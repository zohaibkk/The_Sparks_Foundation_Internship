# %% [markdown]
# <a href="https://colab.research.google.com/github/zohaibkk/The_Sparks_Foundation_Internship/blob/main/Task_8_Covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('owid-covid-data_2.csv')
df.head()
df
# Out:
#       iso_code      continent     location        date  total_cases  \
# 0          AFG           Asia  Afghanistan  2020-01-03          NaN
# 1          AFG           Asia  Afghanistan  2020-01-04          NaN
# 2          AFG           Asia  Afghanistan  2020-01-05          NaN
# 3          AFG           Asia  Afghanistan  2020-01-06          NaN
# 4          AFG           Asia  Afghanistan  2020-01-07          NaN
# ...        ...            ...          ...         ...          ...
# 70311      CUB  North America         Cuba  2020-03-17          4.0
# 70312      CUB  North America         Cuba  2020-03-18          5.0
# 70313      CUB  North America         Cuba  2020-03-19         10.0
# 70314      CUB  North America         Cuba  2020-03-20         11.0
# 70315      CUB  North America         Cuba        2020          NaN
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            0.0                 NaN           NaN         0.0
# 1            0.0                 NaN           NaN         0.0
# 2            0.0                 NaN           NaN         0.0
# 3            0.0                 NaN           NaN         0.0
# 4            0.0                 NaN           NaN         0.0
# ...          ...                 ...           ...         ...
# 70311        0.0               0.571           NaN         0.0
# 70312        1.0               0.714           NaN         0.0
# 70313        5.0               1.429           1.0         1.0
# 70314        1.0               1.143           1.0         0.0
# 70315        NaN                 NaN           NaN         NaN
#
#        new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 0                      NaN  ...           NaN                  37.746
# 1                      NaN  ...           NaN                  37.746
# 2                      NaN  ...           NaN                  37.746
# 3                      NaN  ...           NaN                  37.746
# 4                      NaN  ...           NaN                  37.746
# ...                    ...  ...           ...                     ...
# 70311                0.000  ...          53.3                  85.198
# 70312                0.000  ...          53.3                  85.198
# 70313                0.143  ...          53.3                  85.198
# 70314                0.143  ...          53.3                  85.198
# 70315                  NaN  ...           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 70311                         5.2            78.80                    0.783
# 70312                         5.2            78.80                    0.783
# 70313                         5.2            78.80                    0.783
# 70314                         5.2            78.80                    0.783
# 70315                         NaN              NaN                      NaN
#
#        population  excess_mortality_cumulative_absolute  \
# 0      41128772.0                                   NaN
# 1      41128772.0                                   NaN
# 2      41128772.0                                   NaN
# 3      41128772.0                                   NaN
# 4      41128772.0                                   NaN
# ...           ...                                   ...
# 70311  11212198.0                                   NaN
# 70312  11212198.0                                   NaN
# 70313  11212198.0                                   NaN
# 70314  11212198.0                                   NaN
# 70315         NaN                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                              NaN               NaN
# ...                            ...               ...
# 70311                          NaN               NaN
# 70312                          NaN               NaN
# 70313                          NaN               NaN
# 70314                          NaN               NaN
# 70315                          NaN               NaN
#
#        excess_mortality_cumulative_per_million
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 70311                                      NaN
# 70312                                      NaN
# 70313                                      NaN
# 70314                                      NaN
# 70315                                      NaN
#
# [70316 rows x 67 columns]

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  6.565900e+04  7.026600e+04        7.000100e+04  6.299100e+04
# mean   3.991954e+06  7.294484e+03        7.321623e+03  4.291082e+04
# std    2.336342e+07  1.100034e+05        1.063422e+05  1.803945e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.835000e+03  0.000000e+00        7.140000e-01  1.090000e+02
# 50%    6.164300e+04  4.000000e+00        2.614300e+01  8.320000e+02
# 75%    5.524540e+05  2.640000e+02        4.548570e+02  9.841500e+03
# max    3.004589e+08  7.213802e+06        6.109825e+06  1.632724e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  70270.000000         70005.000000             65659.000000
# mean      48.178412            48.360274             91205.098781
# std      290.032936           280.378524            137182.319087
# min        0.000000             0.000000                 0.000000
# 25%        0.000000             0.000000              2129.383500
# 50%        0.000000             0.143000             20900.611000
# 75%        4.000000             5.429000            117821.953500
# max    11447.000000          5722.286000            691582.666000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           70266.000000                    70001.000000
# mean              136.896103                      137.410439
# std               764.748653                      450.483716
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.140000
# 50%                 0.355000                        6.711000
# 75%                39.835250                       92.299000
# max             38481.443000                     9383.350000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count              62991.000000  ...  41953.000000            31134.000000
# mean                 880.464377  ...     32.258644               47.644292
# std                 1155.921359  ...     12.731953               33.466567
# min                    0.000000  ...     12.300000                2.735000
# 25%                   29.651000  ...     17.900000               15.574000
# 50%                  291.758000  ...     31.400000               37.746000
# 75%                 1460.990000  ...     44.400000               83.741000
# max                 5662.527000  ...     53.300000               97.164000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                50053.000000     67609.000000             56803.000000
# mean                     2.991410        73.434181                 0.716648
# std                      2.306644         7.872215                 0.149900
# min                      0.400000        53.280000                 0.397000
# 25%                      1.300000        69.820000                 0.581000
# 50%                      2.200000        75.880000                 0.765000
# 75%                      4.200000        78.570000                 0.823000
# max                     11.000000        83.920000                 0.944000
#
#          population  excess_mortality_cumulative_absolute  \
# count  7.031500e+04                           2038.000000
# mean   1.636443e+08                          36141.927511
# std    6.949758e+08                          94457.116780
# min    1.587700e+04                          -8543.400000
# 25%    4.490020e+05                            171.350003
# 50%    6.781955e+06                          15045.198500
# 75%    2.617741e+07                          30832.224000
# max    4.721383e+09                         889935.300000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  2038.000000       2038.000000
# mean                     10.679823         13.179014
# std                      11.578238         24.344507
# min                     -27.640000        -66.400000
# 25%                       2.270000         -0.025000
# 50%                       8.705000          6.780000
# 75%                      17.747500         17.347500
# max                      56.240000        245.440000
#
#        excess_mortality_cumulative_per_million
# count                              2038.000000
# mean                               1937.052357
# std                                2413.118679
# min                               -1045.504300
# 25%                                  98.572480
# 50%                                1153.321700
# 75%                                2814.545600
# max                               10292.916000
#
# [8 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70316 entries, 0 to 70315
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    70316 non-null  object
#  1   continent                                   67610 non-null  object
#  2   location                                    70316 non-null  object
#  3   date                                        70316 non-null  object
#  4   total_cases                                 65659 non-null  float64
#  5   new_cases                                   70266 non-null  float64
#  6   new_cases_smoothed                          70001 non-null  float64
#  7   total_deaths                                62991 non-null  float64
#  8   new_deaths                                  70270 non-null  float64
#  9   new_deaths_smoothed                         70005 non-null  float64
#  10  total_cases_per_million                     65659 non-null  float64
#  11  new_cases_per_million                       70266 non-null  float64
#  12  new_cases_smoothed_per_million              70001 non-null  float64
#  13  total_deaths_per_million                    62991 non-null  float64
#  14  new_deaths_per_million                      70270 non-null  float64
#  15  new_deaths_smoothed_per_million             70005 non-null  float64
#  16  reproduction_rate                           41608 non-null  float64
#  17  icu_patients                                8337 non-null   float64
#  18  icu_patients_per_million                    8337 non-null   float64
#  19  hosp_patients                               6478 non-null   float64
#  20  hosp_patients_per_million                   6478 non-null   float64
#  21  weekly_icu_admissions                       1219 non-null   float64
#  22  weekly_icu_admissions_per_million           1219 non-null   float64
#  23  weekly_hosp_admissions                      2428 non-null   float64
#  24  weekly_hosp_admissions_per_million          2428 non-null   float64
#  25  total_tests                                 14803 non-null  float64
#  26  new_tests                                   13828 non-null  float64
#  27  total_tests_per_thousand                    14803 non-null  float64
#  28  new_tests_per_thousand                      13828 non-null  float64
#  29  new_tests_smoothed                          20970 non-null  float64
#  30  new_tests_smoothed_per_thousand             20970 non-null  float64
#  31  positive_rate                               19893 non-null  float64
#  32  tests_per_case                              19428 non-null  float64
#  33  tests_units                                 21878 non-null  object
#  34  total_vaccinations                          15665 non-null  float64
#  35  people_vaccinated                           13950 non-null  float64
#  36  people_fully_vaccinated                     13970 non-null  float64
#  37  total_boosters                              7797 non-null   float64
#  38  new_vaccinations                            12559 non-null  float64
#  39  new_vaccinations_smoothed                   38578 non-null  float64
#  40  total_vaccinations_per_hundred              15665 non-null  float64
#  41  people_vaccinated_per_hundred               13950 non-null  float64
#  42  people_fully_vaccinated_per_hundred         13970 non-null  float64
#  43  total_boosters_per_hundred                  7797 non-null   float64
#  44  new_vaccinations_smoothed_per_million       38578 non-null  float64
#  45  new_people_vaccinated_smoothed              38257 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  38257 non-null  float64
#  47  stringency_index                            44934 non-null  float64
#  48  population_density                          63559 non-null  float64
#  49  median_age                                  56809 non-null  float64
#  50  aged_65_older                               56809 non-null  float64
#  51  aged_70_older                               56809 non-null  float64
#  52  gdp_per_capita                              59431 non-null  float64
#  53  extreme_poverty                             36475 non-null  float64
#  54  cardiovasc_death_rate                       59503 non-null  float64
#  55  diabetes_prevalence                         62209 non-null  float64
#  56  female_smokers                              41953 non-null  float64
#  57  male_smokers                                41953 non-null  float64
#  58  handwashing_facilities                      31134 non-null  float64
#  59  hospital_beds_per_thousand                  50053 non-null  float64
#  60  life_expectancy                             67609 non-null  float64
#  61  human_development_index                     56803 non-null  float64
#  62  population                                  70315 non-null  float64
#  63  excess_mortality_cumulative_absolute        2038 non-null   float64
#  64  excess_mortality_cumulative                 2038 non-null   float64
#  65  excess_mortality                            2038 non-null   float64
#  66  excess_mortality_cumulative_per_million     2038 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 35.9+ MB

# %%
df.shape
# Out:
# (70316, 67)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 67)

# %%
df.count()
# Out:
# iso_code                                   70316
# continent                                  67610
# location                                   70316
# date                                       70316
# total_cases                                65659
#                                            ...
# population                                 70315
# excess_mortality_cumulative_absolute        2038
# excess_mortality_cumulative                 2038
# excess_mortality                            2038
# excess_mortality_cumulative_per_million     2038
# Length: 67, dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                                       0
# continent                                   2706
# location                                       0
# date                                           0
# total_cases                                 4657
#                                            ...
# population                                     1
# excess_mortality_cumulative_absolute       68278
# excess_mortality_cumulative                68278
# excess_mortality                           68278
# excess_mortality_cumulative_per_million    68278
# Length: 67, dtype: int64

# %%
df1 = df[['date','total_cases','new_cases','total_deaths','new_tests','total_tests']]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-01-03          NaN        0.0           NaN        NaN          NaN
# 1  2020-01-04          NaN        0.0           NaN        NaN          NaN
# 2  2020-01-05          NaN        0.0           NaN        NaN          NaN
# 3  2020-01-06          NaN        0.0           NaN        NaN          NaN
# 4  2020-01-07          NaN        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)
df1.set_index('date', inplace = True)
# Out:
# <ipython-input-10-de3d67cace36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.date = pd.to_datetime(df.date)

# %%
df1.head()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-01-03          NaN        0.0           NaN        NaN          NaN
# 2020-01-04          NaN        0.0           NaN        NaN          NaN
# 2020-01-05          NaN        0.0           NaN        NaN          NaN
# 2020-01-06          NaN        0.0           NaN        NaN          NaN
# 2020-01-07          NaN        0.0           NaN        NaN          NaN

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_deaths = df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_tests = df1[['new_tests']]
new_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_tests = df1[['total_tests']]
total_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
df_rm = pd.concat([total_cases.rolling(12).mean(), total_deaths.rolling(12).mean()])
df_rm.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);
